# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
housing = pd.read_csv(r'/content/real_estate.csv', encoding='ISO-8859-1')
housing
# Out:
#          status  bed  bath  acre_lot        city          state  zip_code  \
# 0      for_sale  3.0   2.0      0.12    Adjuntas    Puerto Rico     601.0
# 1      for_sale  4.0   2.0      0.08    Adjuntas    Puerto Rico     601.0
# 2      for_sale  2.0   1.0      0.15  Juana Diaz    Puerto Rico     795.0
# 3      for_sale  4.0   2.0      0.10       Ponce    Puerto Rico     731.0
# 4      for_sale  6.0   2.0      0.05    Mayaguez    Puerto Rico     680.0
# ...         ...  ...   ...       ...         ...            ...       ...
# 99995  for_sale  3.0   3.0       NaN      Hudson  Massachusetts    1749.0
# 99996  for_sale  2.0   1.0      0.34      Auburn  Massachusetts    1501.0
# 99997  for_sale  3.0   2.0      1.01  Shrewsbury  Massachusetts    1545.0
# 99998  for_sale  3.0   2.0      0.12   Worcester  Massachusetts    1604.0
# 99999  for_sale  3.0   3.0     21.67     Grafton  Massachusetts    1536.0
#
#        house_size prev_sold_date     price
# ...

# %%
housing_filtered = housing[housing['state'].isin(['Puerto Rico','Massachusetts','New York'])]

# %%
sns.set_theme(style='whitegrid')
sns.set_style('darkgrid')
sns.set_palette('deep')
sns.barplot(housing_filtered, x='state', y='price', estimator='median')
# Out:
# <Axes: xlabel='state', ylabel='price'>

# %%
housing_filt = housing[housing['house_size']< 10000]
sns.regplot(housing_filt, x='house_size', y='price', line_kws={'color':'red'})
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
iris = sns.load_dataset('iris')
iris.head(45)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
sns.pairplot(iris, hue='species')

# %%
sns.stripplot(x='species', y='sepal_length', data=iris)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.violinplot(x='species', y='sepal_length', data=iris, hue='species')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
housing_cfilt = housing.drop(columns=['status','zip_code','city','state','prev_sold_date'])
housing_cfilt
housing_cfilt.corr()
# Out:
#                  bed      bath  acre_lot  house_size     price
# bed         1.000000  0.715531  0.000135    0.184645  0.199924
# bath        0.715531  1.000000  0.005751    0.226905  0.383401
# acre_lot    0.000135  0.005751  1.000000    0.045852  0.018991
# house_size  0.184645  0.226905  0.045852    1.000000  0.171422
# price       0.199924  0.383401  0.018991    0.171422  1.000000

# %%
spearman_correlation = housing_cfilt.corr(method='spearman')
spearman_correlation
pearson_correlation = housing_cfilt.corr(method='pearson')
pearson_correlation
kendall_correlation = housing_cfilt.corr(method='kendall')
kendall_correlation
# Out:
#                  bed      bath  acre_lot  house_size     price
# bed         1.000000  0.498775 -0.013599    0.524954  0.202597
# bath        0.498775  1.000000  0.177513    0.632030  0.449005
# acre_lot   -0.013599  0.177513  1.000000    0.196272  0.102153
# house_size  0.524954  0.632030  0.196272    1.000000  0.479540
# price       0.202597  0.449005  0.102153    0.479540  1.000000

# %%
fig, axs = plt.subplots(3,1, figsize=(10,7))
sns.heatmap(spearman_correlation, ax=axs[0], annot=True, cmap='coolwarm')
axs[0].set_title('Spearman Correlation')
sns.heatmap(pearson_correlation, ax=axs[1], annot=True,cmap='coolwarm')
axs[1].set_title('Pearson Correlation')
sns.heatmap(kendall_correlation, ax=axs[2], annot=True,cmap='coolwarm')
axs[2].set_title('Kendall Correlation')
plt.tight_layout()
plt.show()
